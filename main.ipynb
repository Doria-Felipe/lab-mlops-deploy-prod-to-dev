# %% [markdown]
# # LAB | MLOps Deployment from PROD to DEV

# %% [markdown]
# ## Objective
# In this exercise, you will work in pairs to simulate the process of deploying code from a development environment (DEV) to a production environment (PRD). One student will act as the developer pushing code, while the other will be the gatekeeper ensuring the code runs correctly.

# %% [markdown]
# ## Instructions
#
# ### Step 1: Form Pairs
# - Done.

# %% [markdown]
# ### Step 2: Developer Role
# I created a brach from the CIFAR-10 CNN project and cloned it.

# %% [markdown]
# ### Step 3: Gatekeeper

# %% [markdown]
# As the gate keeper I used the cloned repo as if it was not mine and revised it. I installed the requirements from requirements.txt and created a .venv with that information.
#
# I finally tried to run the project.
#
# After troubleshooting the address of my file it ran smoothly.

# %% [markdown]
# ### Step 4: Swap Roles and Repeat
# Done

# %% [markdown]
# The test went well, but it is necessary to check the dependencies and be careful for the correct addresses to be in the code.
